# %% [markdown]
# <a href="https://colab.research.google.com/github/vmittal231/cognitive-computing-assignment/blob/main/Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question 1:

# %%
import numpy as np
import matplotlib.pyplot as p
M=int(input("Enter the value for M:"))
x=np.linspace(-10,10,50)
y1=M*x**2
y2=M*np.sin(x)
p.plot(x,y1,color='r',linestyle='dashed',label='dashed')
p.plot(x,y2,color='g',linestyle='solid',label='solid')
p.legend()
p.grid(True)
p.title(f'Plots of y={M}x^2 and y={M}sin(x)')
p.show()
# Out:
# Enter the value for M:5

# %% [markdown]
# Question 2:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as p
import seaborn as sns
subject=["AI","Cognitive","DBMS","Probability","DAA"]
scores=[90,87,88,97,85]
df=pd.DataFrame({"Subject":subject,"Scores":scores})
graph=sns.barplot(x='Subject',y='Scores',data=df,palette='viridis',legend=False)
for bar in graph.patches:
  height=bar.get_height()
  x_coord=bar.get_x()+bar.get_width()/2
  graph.text(x_coord,height+2,f'{int(height)}')
p.title('Scores in Subjects')
p.legend(title="Subjects", labels=df["Subject"].unique())
p.grid(alpha=0.4)
p.show()
# Out:
# <ipython-input-2-82291b55e5af>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   graph=sns.barplot(x='Subject',y='Scores',data=df,palette='viridis',legend=False)

# %% [markdown]
# Question 3:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as p
import seaborn as sns
np.random.seed(102317012)
data=np.random.randn(50)
fig,ax=p.subplots(2,2)
ax[0,0].plot(np.cumsum(data),color='b',marker='o')
ax[0,0].set_title('Line Plot Showing Cumulative Sum')
ax[0,0].grid(alpha=0.4)

ax[0,1].scatter(range(50),data+np.random.randn(50)*0.2,color='r')
ax[0,1].set_title('Scatter Plot')
ax[0,1].grid(alpha=0.4)
p.show()

# %% [markdown]
# Question 4:

# %%
from google.colab import files
uploaded = files.upload() #uploading file to google colab
# Out:
#      <input type="file" id="files-4c8128d6-d0d3-48ac-940a-acd28703ab8b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4c8128d6-d0d3-48ac-940a-acd28703ab8b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as p
import seaborn as sns
df=pd.read_csv("company_sales_data.csv")
sns.lineplot(data=df,x='month_number',y='total_profit',color='b',marker='o')

p.grid(alpha=0.4)
p.title('Line Plot')
p.show()
print()
for column in df[1:-1]:
  sns.lineplot(data=df,x='month_number',y=column,color='b',marker='o')

p.grid(alpha=0.4)
p.title('Multiline Plot')
p.show()
print()
p.bar(df['month_number'], df['total_profit'], label='Total Profit')
p.xlabel("Month")
p.ylabel("Values")
p.title("Bar Chart of Total Profit")

p.grid(alpha=0.4)
p.show()
